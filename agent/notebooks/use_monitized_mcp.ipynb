# %%
from paylink.integrations.langchain_tools import PayLinkTools


client = PayLinkTools(base_url="http://0.0.0.0:5003/mcp")

tools = client.list_tools()

print(tools)
# Out:
# [StructuredTool(name='add', description='Add two integers', args_schema=<class 'paylink.integrations.langchain_tools.addArgs'>, func=<function _build_structured_tool.<locals>._run at 0x110bc5620>, coroutine=<function _build_structured_tool.<locals>._arun at 0x10a564fe0>), StructuredTool(name='subtract', description='Subtract two integers', args_schema=<class 'paylink.integrations.langchain_tools.subtractArgs'>, func=<function _build_structured_tool.<locals>._run at 0x110bc5ee0>, coroutine=<function _build_structured_tool.<locals>._arun at 0x110bc5b20>)]

# %%
result = client.call_tool("add", {"a": 5, "b": 3})
result
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = client.call_tool("add", {"a": 5, "b": 3})
#       2 result
#
# AttributeError: 'PayLinkTools' object has no attribute 'call_tool'
